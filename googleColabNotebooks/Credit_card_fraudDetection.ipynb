# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushnigamsworld/mlNotez/blob/master/googleColabNotebooks/Credit_card_fraudDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# %%
data = pd.read_csv('creditcard.csv')

# %%
print(data.columns)
#print(data.head())
#print(data[data['Class'] == 1])
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'], dtype='object')

# %%
plt.hist(data['Class'])
plt.show()

# %%
print(data.shape)
print(data[data['Class'] == 1].shape)
# Out:
# (284807, 31)
# (492, 31)

# %%
print(data.describe())
# Out:
#                 Time            V1            V2            V3            V4            V5            V6            V7            V8            V9           V10           V11           V12           V13           V14           V15           V16           V17           V18           V19           V20           V21           V22           V23           V24           V25           V26           V27           V28         Amount          Class
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000  284807.000000
# ...

# %%
#taking a sample of data
data = data.sample(frac=0.1, random_state=1)

print(data.shape)
# Out:
# (28481, 31)

# %%
 # histogram of each parameter
  data.hist(figsize = (20, 20))
  plt.show()

# %%
# find number of fraud cases
Fraud = data[data['Class'] == 1]
Valid = data[data['Class'] == 0]

outlier_fraction = len(Fraud) / float(len(Valid))
print(outlier_fraction)

print('Fraud cases: {}'.format(len(Fraud)))
print('Valid cases: {}'.format(len(Valid)))
# Out:
# 0.0017234102419808666
# Fraud cases: 49
# Valid cases: 28432
